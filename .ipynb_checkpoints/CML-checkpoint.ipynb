# %% [markdown]
# ## Import Data

# %%
import pandas as pd
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import DBSCAN
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ## Data reduction due to large number of dataset

# %%
pd.options.display.float_format = '{:.2f}'.format
df = pd.read_parquet('yellow_tripdata_2024-01.parquet')
reduced_df = df.sample(n=25000,random_state=42)
reduced_df.to_csv('./reduced_dataset.csv', index=False)
# df.head()
reduced_df.isnull().sum()
# Out:
# VendorID                    0
# tpep_pickup_datetime        0
# tpep_dropoff_datetime       0
# passenger_count          1182
# trip_distance               0
# RatecodeID               1182
# store_and_fwd_flag       1182
# PULocationID                0
# DOLocationID                0
# payment_type                0
# fare_amount                 0
# extra                       0
# mta_tax                     0
# tip_amount                  0
# tolls_amount                0
# improvement_surcharge       0
# total_amount                0
# congestion_surcharge     1182
# Airport_fee              1182
# dtype: int64

# %% [markdown]
# ## Describe data

# %%
reduced_df.describe()
# Out:
#        VendorID        tpep_pickup_datetime       tpep_dropoff_datetime  \
# count  25000.00                       25000                       25000
# mean       1.75  2024-01-17 01:33:50.376959  2024-01-17 01:48:59.371440
# min        1.00         2023-12-31 23:58:35         2024-01-01 00:13:06
# 25%        1.00  2024-01-09 16:00:28.250000  2024-01-09 16:22:25.750000
# 50%        2.00  2024-01-17 11:43:07.500000         2024-01-17 12:02:31
# 75%        2.00  2024-01-24 19:38:42.750000  2024-01-24 19:54:15.500000
# max        2.00         2024-01-31 23:56:06         2024-02-01 07:56:40
# std        0.43                         NaN                         NaN
#
#        passenger_count  trip_distance  RatecodeID  PULocationID  DOLocationID  \
# count         23818.00       25000.00    23818.00      25000.00      25000.00
# mean              1.33           3.21        2.12        165.82        165.49
# min               0.00           0.00        1.00          1.00          1.00
# 25%               1.00           1.00        1.00        132.00        116.00
# 50%               1.00           1.68        1.00        162.00        162.00
# 75%               1.00           3.10        1.00        234.00        234.00
# max               8.00          50.40       99.00        265.00        265.00
# std               0.84           4.31       10.09         63.25         69.03
#
#        payment_type  fare_amount    extra  mta_tax  tip_amount  tolls_amount  \
# count      25000.00     25000.00 25000.00 25000.00    25000.00      25000.00
# mean           1.16        18.13     1.46     0.48        3.32          0.53
# min            0.00      -110.10    -7.50    -0.50       -0.01         -8.38
# 25%            1.00         8.60     0.00     0.50        0.98          0.00
# 50%            1.00        12.80     1.00     0.50        2.66          0.00
# 75%            1.00        19.82     2.50     0.50        4.10          0.00
# max            4.00       258.00    11.75     0.50      422.70         85.00
# std            0.58        17.73     1.82     0.12        4.68          2.16
#
#        improvement_surcharge  total_amount  congestion_surcharge  Airport_fee
# count               25000.00      25000.00              23818.00     23818.00
# mean                    0.98         26.76                  2.26         0.14
# min                    -1.00       -116.85                 -2.50        -1.75
# 25%                     1.00         15.30                  2.50         0.00
# 50%                     1.00         20.00                  2.50         0.00
# 75%                     1.00         28.50                  2.50         0.00
# max                     1.00        453.55                  2.50         1.75
# std                     0.22         22.59                  0.82         0.49

# %% [markdown]
# ## Data Preprocessing / Transformation
# ### Feature Engineering - pickup datetime
#
# 1) The dataset has columns "pep_pickup_datetime" "tpep_dropoff_datetime" for that creatig new column Time slot with (Morning,Evening,night,afternoon) for better analysis using ColumnTransformer

# %%
class TimeSlotTransformer(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        time_slots = X.apply(lambda x: self.get_time_slot(x['tpep_pickup_datetime']), axis=1)
        return np.array(time_slots).reshape(-1, 1)
    
    def get_time_slot(self, time):
        if 5 <= time.hour < 12:
            return 'Morning'
        elif 12 <= time.hour < 17:
            return 'Afternoon'
        elif 17 <= time.hour < 21:
            return 'Evening'
        else:
            return 'Night'

pipeline = Pipeline(steps=[
    ('time_slot_transformer', ColumnTransformer(
        transformers=[
            ('time_slot', TimeSlotTransformer(), ['tpep_pickup_datetime'])
        ],
        remainder='drop'  # This drops other columns not specified in transformers
    ))
])
time_slots = pipeline.fit_transform(reduced_df).flatten()
time_slots
# Out:
# array(['Afternoon', 'Night', 'Night', ..., 'Evening', 'Night', 'Night'],
#       dtype=object)

# %% [markdown]
# 2) Creating a separate column which has the data for trip distance (short, long, medium)
# but the the column has outliers in it and random values like 300,000 miles
# so creating a caping thershold 278 miles because one rows has 277 miles with correct data

# %% [markdown]
# ## Feature Engineering - trip distance
# - (short, medium, long )

# %%
# cap_threshold = df['trip_distance'].quantile(0.99)
# # cap_threshold = 278
# df['trip_distance'] = df['trip_distance'].clip(upper=cap_threshold)
reduced_df['trip_distance'].describe()
short_threshold = reduced_df['trip_distance'].quantile(0.33)
long_threshold = reduced_df['trip_distance'].quantile(0.66)

# Create a new column for categorization
def categorize_distance(distance):
    if distance <= short_threshold:
        return 'short'
    elif distance <= long_threshold:
        return 'medium'
    else:
        return 'long'

distance_slots = reduced_df['trip_distance'].apply(categorize_distance)
# type(distance_slots)
time_slots
# Out:
# array(['Afternoon', 'Night', 'Night', ..., 'Evening', 'Night', 'Night'],
#       dtype=object)

# %% [markdown]
# ## Create duration column

# %%
reduced_df['duration'] = (reduced_df['tpep_dropoff_datetime'] - reduced_df['tpep_pickup_datetime'])/np.timedelta64(1,'m')
reduced_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25000 entries, 1725696 to 2134053
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               25000 non-null  int32
#  1   tpep_pickup_datetime   25000 non-null  datetime64[us]
#  2   tpep_dropoff_datetime  25000 non-null  datetime64[us]
#  3   passenger_count        23818 non-null  float64
#  4   trip_distance          25000 non-null  float64
#  5   RatecodeID             23818 non-null  float64
#  6   store_and_fwd_flag     23818 non-null  object
#  7   PULocationID           25000 non-null  int32
#  8   DOLocationID           25000 non-null  int32
#  9   payment_type           25000 non-null  int64
#  10  fare_amount            25000 non-null  float64
#  11  extra                  25000 non-null  float64
#  12  mta_tax                25000 non-null  float64
#  13  tip_amount             25000 non-null  float64
#  14  tolls_amount           25000 non-null  float64
#  15  improvement_surcharge  25000 non-null  float64
#  16  total_amount           25000 non-null  float64
#  17  congestion_surcharge   23818 non-null  float64
#  18  Airport_fee            23818 non-null  float64
#  19  duration               25000 non-null  float64
# dtypes: datetime64[us](2), float64(13), int32(3), int64(1), object(1)
# memory usage: 4.2+ MB

# %% [markdown]
# ## Three important column to predict outliers are
# - trip_distance
# - fare_amount
# - duration

# %% [markdown]
# ### Visualizing

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 2))
fig.suptitle('Boxplots for the taxi data')
sns.boxplot(ax=axes[0], x=reduced_df['trip_distance'])
sns.boxplot(ax=axes[1], x=reduced_df['fare_amount'])
sns.boxplot(ax=axes[2], x=reduced_df['duration'])
plt.show();

# %% [markdown]
# ## The trip distance column outliers
# - the trip distance column have 532 zero values out of 25000 which will not have a huge impact on datset so the trip distance column remains same

# %%
sum(reduced_df['trip_distance']==0)
# Out:
# 532

# %% [markdown]
# ## Fare amount outlier

# %%
reduced_df['fare_amount'].describe()
# Out:
# count   25000.00
# mean       18.13
# std        17.73
# min      -110.10
# 25%         8.60
# 50%        12.80
# 75%        19.82
# max       258.00
# Name: fare_amount, dtype: float64

# %%
def oulierDetect(name_list,factor):
    for x in name_list:
        # if values less than zeros are considered as zeros
        reduced_df.loc[reduced_df[x] < 0, x] = 0
        # seting q3 value
        q3 = reduced_df[x].quantile(0.75)
        # setting the upper cap
        upper_cap = q3 + (factor * (q3 - reduced_df[x].quantile(0.25)))
        
        reduced_df.loc[reduced_df[x] > upper_cap, x] = upper_cap

# %%
oulierDetect(['fare_amount'], 6)
reduced_df['fare_amount'].describe()
# Out:
# count   25000.00
# mean       18.24
# std        16.22
# min         0.00
# 25%         8.60
# 50%        12.80
# 75%        19.82
# max        87.14
# Name: fare_amount, dtype: float64

# %% [markdown]
# ## Duration Outlier detection

# %%
oulierDetect(['duration'], 6)
reduced_df['duration'].describe()
# Out:
# count   25000.00
# mean       14.76
# std        11.62
# min         0.00
# 25%         7.12
# 50%        11.55
# 75%        18.70
# max        88.20
# Name: duration, dtype: float64

# %%
reduced_df['pickDrop'] = reduced_df['PULocationID'].astype(str) + ' ' + reduced_df['DOLocationID'].astype(str)
reduced_df['pickDrop'].head(2)
# Out:
# 1725696    132 233
# 1581136     163 75
# Name: pickDrop, dtype: object

# %% [markdown]
# ## Mean Distance Column

# %%
pickDrop_Dis = reduced_df.groupby('pickDrop').mean(numeric_only=True)[['trip_distance']]
pickDrop_Dis[:10]

pickDrop_Dis_dict = pickDrop_Dis.to_dict()


pickDrop_Dis_dict = pickDrop_Dis_dict['trip_distance']

# len(pickDrop_Dis_dict)

reduced_df['mean_dis'] = reduced_df['pickDrop']


reduced_df['mean_dis'] = reduced_df['mean_dis'].map(pickDrop_Dis_dict)


reduced_df[(reduced_df['PULocationID']==100) & (reduced_df['DOLocationID']==231)][['mean_dis']]
# Out:
#          mean_dis
# 2779147      3.09
# 2947575      3.09
# 71435        3.09
# 1542045      3.09
# 2849538      3.09
# 2211672      3.09
# 2446692      3.09

# %% [markdown]
# ## Mean Duriation Column

# %%
grouped = reduced_df.groupby('pickDrop').mean(numeric_only=True)[['duration']]
grouped

grouped_dict = grouped.to_dict()
grouped_dict = grouped_dict['duration']

reduced_df['mean_duration'] = reduced_df['pickDrop']
reduced_df['mean_duration'] = reduced_df['mean_duration'].map(grouped_dict)

reduced_df[(reduced_df['PULocationID']==100) & (reduced_df['DOLocationID']==231)][['mean_duration']]
# Out:
#          mean_duration
# 2779147          21.85
# 2947575          21.85
# 71435            21.85
# 1542045          21.85
# 2849538          21.85
# 2211672          21.85
# 2446692          21.85

# %%
reduced_df['dd'] = reduced_df['tpep_pickup_datetime'].dt.day_name().str.lower()

reduced_df['mm'] = reduced_df['tpep_pickup_datetime'].dt.strftime('%b').str.lower()

reduced_df['dd']
# Out:
# 1725696     saturday
# 1581136     thursday
# 19137         monday
# 1682810       friday
# 511035      saturday
#              ...
# 2863684    wednesday
# 1902561       monday
# 2797172    wednesday
# 2048501    wednesday
# 2134053    wednesday
# Name: dd, Length: 25000, dtype: object

# %%
reduced_df['peek_t'] = reduced_df['tpep_pickup_datetime'].dt.hour

# If day is Saturday or Sunday, impute 0 in `rush_hour` column
reduced_df.loc[reduced_df['dd'].isin(['saturday', 'sunday']), 'peek_t'] = 0
def peek_analzer(hour):
    if 6 <= hour['peek_t'] < 10:
        val = 1
    elif 16 <= hour['peek_t'] < 20:
        val = 1
    else:
        val = 0
    return val
reduced_df['peek_t'] = reduced_df.apply(peek_analzer, axis=1)
reduced_df.head()
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 1725696         2  2024-01-20 13:31:30   2024-01-20 14:03:25             2.00
# 1581136         2  2024-01-18 21:52:46   2024-01-18 22:03:21             1.00
# 19137           2  2024-01-01 03:43:58   2024-01-01 03:50:47             2.00
# 1682810         1  2024-01-19 22:20:12   2024-01-19 22:50:12             1.00
# 511035          2  2024-01-06 22:41:50   2024-01-06 22:43:24             1.00
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 1725696          17.14        2.00                  N           132
# 1581136           2.49        1.00                  N           163
# 19137             1.84        1.00                  N           127
# 1682810           3.60        1.00                  N           186
# 511035            0.04        1.00                  N           238
#
#          DOLocationID  payment_type  ...  total_amount  congestion_surcharge  \
# 1725696           233             1  ...         90.96                  2.50
# 1581136            75             1  ...         22.50                  2.50
# 19137              20             2  ...         12.50                  0.00
# 1682810           263             1  ...         33.95                  2.50
# 511035            238             2  ...          6.20                  0.00
#
#          Airport_fee  duration  pickDrop  mean_dis  mean_duration        dd  \
# 1725696         1.75     31.92   132 233     17.06          30.96  saturday
# 1581136         0.00     10.58    163 75      2.50          15.03  thursday
# 19137           0.00      6.82    127 20      1.84           6.82    monday
# 1682810         0.00     30.00   186 263      3.96          24.08    friday
# 511035          0.00      1.57   238 238      0.56           4.05  saturday
#
#           mm  peek_t
# 1725696  jan       0
# 1581136  jan       0
# 19137    jan       0
# 1682810  jan       0
# 511035   jan       0
#
# [5 rows x 26 columns]

# %% [markdown]
# ## The mean duration correlates with target value

# %%
sns.set(style='whitegrid')
f = plt.figure()
f.set_figwidth(5)
f.set_figheight(5)
sns.regplot(x=reduced_df['mean_duration'], y=reduced_df['fare_amount'],
            scatter_kws={'alpha':0.5, 's':5},
            line_kws={'color':'red'})
plt.ylim(0, 70)
plt.xlim(0, 70)
plt.title('Mean duration x fare amount')
plt.show()

# %%
reduced_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25000 entries, 1725696 to 2134053
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               25000 non-null  int32
#  1   tpep_pickup_datetime   25000 non-null  datetime64[us]
#  2   tpep_dropoff_datetime  25000 non-null  datetime64[us]
#  3   passenger_count        23818 non-null  float64
#  4   trip_distance          25000 non-null  float64
#  5   RatecodeID             23818 non-null  float64
#  6   store_and_fwd_flag     23818 non-null  object
#  7   PULocationID           25000 non-null  int32
#  8   DOLocationID           25000 non-null  int32
#  9   payment_type           25000 non-null  int64
#  10  fare_amount            25000 non-null  float64
#  11  extra                  25000 non-null  float64
#  12  mta_tax                25000 non-null  float64
#  13  tip_amount             25000 non-null  float64
#  14  tolls_amount           25000 non-null  float64
#  15  improvement_surcharge  25000 non-null  float64
#  16  total_amount           25000 non-null  float64
#  17  congestion_surcharge   23818 non-null  float64
#  18  Airport_fee            23818 non-null  float64
#  19  duration               25000 non-null  float64
#  20  pickDrop               25000 non-null  object
#  21  mean_dis               25000 non-null  float64
#  22  mean_duration          25000 non-null  float64
#  23  dd                     25000 non-null  object
#  24  mm                     25000 non-null  object
#  25  peek_t                 25000 non-null  int64
# dtypes: datetime64[us](2), float64(15), int32(3), int64(2), object(4)
# memory usage: 5.4+ MB

# %%
rdDf = reduced_df.copy()

rdDf = rdDf.drop(['tpep_dropoff_datetime', 'tpep_pickup_datetime',
               'trip_distance', 'RatecodeID', 'store_and_fwd_flag', 'PULocationID', 'DOLocationID',
               'payment_type', 'extra', 'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
               'total_amount', 'tpep_dropoff_datetime', 'tpep_pickup_datetime', 'duration','Airport_fee',"congestion_surcharge","pickDrop","dd","mm"
               ], axis=1)

rdDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25000 entries, 1725696 to 2134053
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   VendorID         25000 non-null  int32
#  1   passenger_count  23818 non-null  float64
#  2   fare_amount      25000 non-null  float64
#  3   mean_dis         25000 non-null  float64
#  4   mean_duration    25000 non-null  float64
#  5   peek_t           25000 non-null  int64
# dtypes: float64(4), int32(1), int64(1)
# memory usage: 1.7 MB

# %%
rdDf.corr(method='pearson')
# Out:
#                  VendorID  passenger_count  fare_amount  mean_dis  \
# VendorID             1.00             0.10         0.03      0.03
# passenger_count      0.10             1.00         0.04      0.03
# fare_amount          0.03             0.04         1.00      0.89
# mean_dis             0.03             0.03         0.89      1.00
# mean_duration       -0.02             0.02         0.81      0.86
# peek_t              -0.01            -0.04        -0.02     -0.03
#
#                  mean_duration  peek_t
# VendorID                 -0.02   -0.01
# passenger_count           0.02   -0.04
# fare_amount               0.81   -0.02
# mean_dis                  0.86   -0.03
# mean_duration             1.00   -0.01
# peek_t                   -0.01    1.00

# %% [markdown]
# ## Strongest Correlations:
#
# - fare_amount with mean_dis (0.89)
# - fare_amount with mean_duration (0.81)
# - mean_dis with mean_duration (0.86)

# %% [markdown]
# diffrentiating X and y which is features and target

# %%
X = rdDf.drop(columns=['fare_amount'])

y = rdDf[['fare_amount']]

# Display first few rows
X.head()
